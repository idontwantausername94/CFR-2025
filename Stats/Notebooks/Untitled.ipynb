# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
austin_evictions = pd.read_csv("../../Python/austin_barchart.csv")
print(austin_evictions)
austin_evictions["month"] = pd.to_datetime(austin_evictions["month"])
austin_evictions["month_filings"] = pd.to_datetime(austin_evictions["month_filings"])
plt.plot(austin_evictions["month"], austin_evictions["month_filings"])
#austin_evictions_plot = plt.plot(austin_evictions["month"], ["month_filings"])
#print(austin_evictions_plot)
# Out:
#       month  month_last_day  month_filings  avg_filings  percentage_diff
# 0   01/2020             NaN           1101        957.0         1.150470
# 1   02/2020             NaN           1084        962.5         1.126234
# 2   03/2020             NaN            639        901.5         0.708819
# 3   04/2020             NaN             23        817.5         0.028135
# 4   05/2020             NaN             28        915.0         0.030601
# ..      ...             ...            ...          ...              ...
# 60  01/2025             NaN           1287        957.0         1.344828
# 61  02/2025             NaN           1248        941.5         1.325544
# 62  03/2025             NaN           1235        901.5         1.369939
# 63  04/2025             NaN           1112        817.5         1.360245
# 64  05/2025             NaN           1110        915.0         1.213115
#
# [65 rows x 5 columns]
# ...
