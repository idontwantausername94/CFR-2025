# %% [markdown]
# ## Galaxies in Illustris
#
# Above, we were looking at star particles in simulated galaxies, similar to how we looked at stars in the Milky Way using Gaia data. We can instead look at many galaxies' overall properties, similar to how we looked at galaxies in Galaxy Zoo. We can look at some of the fully evolved galaxies in IllustrisTNG by examining the Illustris_galaxies file in the Data folder.

# %%
# read in the data (Illustris_galaxies.csv)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data1 = pd.read_csv("../Data/Illustris_galaxies.csv")

# %%
# display the data set
data1
# Out:
#        Galaxy ID  Stellar Mass [Mo]     g band     r band  \
# 0              0       3.565573e+12 -23.256830 -24.071047
# 1              1       5.376783e+11 -21.941610 -22.712160
# 2              2       6.034437e+11 -22.199574 -22.951138
# 3              3       1.650696e+11 -21.828701 -22.411537
# 4              4       1.283022e+11 -20.685863 -21.426640
# ...          ...                ...        ...        ...
# 12530     704187       5.030724e+09 -17.602875 -18.358276
# 12531     719337       6.327700e+09 -18.095821 -18.824528
# 12532     727485       5.224962e+09 -17.727982 -18.471638
# 12533     738596       3.874592e+09 -17.392363 -18.134193
# 12534     752194       3.403812e+09 -17.248920 -17.987637
#
#        Probability is spiral
# 0                   0.285813
# 1                   0.817303
# 2                   0.941455
# 3                   0.998825
# 4                   0.113466
# ...                      ...
# 12530               0.411240
# 12531               0.607696
# 12532               0.475961
# 12533               0.542526
# 12534               0.777810
#
# [12535 rows x 5 columns]

# %% [markdown]
# **How many rows are there?**
#
# **Answer:12535**
#
# **How many columns are there?**
#
# **Answer:5**
#
# **Fill in the rows for each corresponding column**
#
# | Column Header | Definition | Unit |
# | :- | :- | :- |
# | Galaxy ID | Arnitrary number used for identity purposes| -
# | Stellar Mass [Mo] | the weight of a galaxy based on the weight of one our sun | Solar Mass
# | g band | Telescope filter for brightness | Magnitude or Color
# | r band | Telescope filter for brightness | Magnitude or Color
# | Probability is spiral | The chance that that particular galaxy is shaped like a spiral | Percentage

# %%
# create two boolean arrays for... 
#... if a galaxy is a spiral galaxy or an elliptical galaxy
# use the same probability cut off that we did with the galaxy zoo
# you can assume a galaxy is elliptical if it is is ...
#... less than 20% chance a spiral galaxy
data1_maybe_spiral = data1["Probability is spiral"]
its_a_spiral = data1_maybe_spiral >= .8
its_an_elliptical = data1_maybe_spiral <= .2

# %% [markdown]
# **What percentage of these galaxies are spirals?**
#
# **Answer: 26.18**
#
# **What percentage of these galaxies are ellipticals?**
#
# **Answer:11.76**

# %%
#fill in the name of the boolean arrays where you see $
print('The percentage of spiral galaxies is', round(sum(its_a_spiral)/len(data1_maybe_spiral) * 100,2), '%')
print('The percentage of elliptical galaxies is', round(sum(its_an_elliptical)/len(data1_maybe_spiral) * 100,2), '%')
# Out:
# The percentage of spiral galaxies is 26.18 %
# The percentage of elliptical galaxies is 11.76 %

# %% [markdown]
# **How do these percentages compare to the ones you found in the Galaxy Zoo data?**
#
# **Answer:**

# %%
# create a single plot showing histograms of the colors of the two types of galaxies 

# import our graphing package and numpy


#the below is optional but makes the font a size I can read more easily
import matplotlib
matplotlib.rc('font', **{'family':'sans-serif', 'size':16}) 

# calculate color
g_band = data1["g band"]
r_band = data1["r band"]
data1_color = g_band - r_band

# separate into spiral and elliptical
data1_maybe_spiral = data1["Probability is spiral"]
its_a_spiral = data1_maybe_spiral >= .8
its_an_elliptical = data1_maybe_spiral <= .2

# create one histogram with elliptical and spiral galaxies on it
plt.hist(data1_color[its_a_spiral]) 
plt.hist(data1_color[its_an_elliptical])
# statistics -- find the mean and standard deviations of the color for... 
#... spirals and ellipticals
# print the stats below
# Out:
# (array([  6.,  11.,  19.,  19.,  22.,  30.,  47., 119., 908., 293.]),
#  array([0.256421, 0.315946, 0.375471, 0.434996, 0.494521, 0.554046,
#         0.613571, 0.673096, 0.732621, 0.792146, 0.851671]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# **Are your results consistent with what you found in Galaxy Zoo?**
#
# **Answer: I don't know**

# %% [markdown]
# ## Mergers
#
# So far, we have confirmed that in at least some ways, the simulated galaxies behave like observed ones! Cool, but let's learn something new! I said that we can use galaxy simulations to learn about mergers. Let's do that! Read in the mergers files and check out what it contains.

# %%
# read in the file mergers.csv
mergers = pd.read_csv("../Data/mergers.csv")

# %%
# examine the data
mergers
# Out:
#        Galaxy ID  Time Since Last Major Merger [Gyr]  Number of Major Mergers  \
# 0              0                            5.740040                        8
# 1              1                            3.956615                        9
# 2              2                            0.799699                        3
# 3              3                            4.126383                        7
# 4              4                            6.980874                        5
# ...          ...                                 ...                      ...
# 12530     704187                           12.554805                        3
# 12531     719337                            9.462953                        1
# 12532     727485                           10.228946                        7
# 12533     738596                           11.317041                        3
# 12534     752194                           12.698000                        2
#
#        Numbber of Minor Mergers
# 0                            16
# 1                             5
# 2                             4
# 3                             5
# 4                             7
# ...                         ...
# 12530                         2
# 12531                         2
# 12532                         1
# 12533                         2
# 12534                         2
#
# [12535 rows x 4 columns]

# %% [markdown]
# **How many rows are there?**
#
# **Answer: 12535**
#
# **How many columns are there?**
#
# **Answer:4**
#
# **Fill in the rows for each corresponding column**
#
# | Column Header | Definition | Unit |
# | :- | :- | :- |
# | Galaxy ID | Number assigned to galaxy for identification purposes | -
# | Time Since Last Major Merger [Gyr] | the amount of time lapsed from when another galaxy was merged with the one in question | Billions of years
# | Number of Major Mergers | How many larger galaxies a particular galaxy merges with (Equal galaxy combines with equal galaxy)|
# | Number of Minor Mergers | How many smaller galaxies a particular galaxy merges with (Host galaxy eats smaller galaxy) |

# %% [markdown]
# # Deliverable
#
# Explore the galaxy data you have in this notebook to make at least one plot that tells us something we haven't explored! Be ready to present. You might want to include statistics.

# %%
# explore the data and make a plot below!
plt.scatter(mergers["Time Since Last Major Merger [Gyr]"], mergers["Number of Major Mergers"], alpha=.05)

plt.xlabel("Time Since Last Merger (Gya)")
plt.ylabel("Number of Major Mergers")
# Out:
# Text(0, 0.5, 'Number of Major Mergers')

# %% [markdown]
# **According to your graph set up...**
#
# **What is the independent variable?**
#
# **Answer: Time Since Last Major Merger [Gyr]**
#
#
# **What is the dependent variable?**
#
# **Answer: Number of Major Mergers**
#
#
# **What could a control variable be?**
#
# **Answer: Time**
#
# **What shapes or trends do you see in the data?**
#
# **Answer: Triangles and Lines**
#
# **What could this mean physically/astronomically?**
#
# **Answer:**
#
# **What further questions does this raise?**
#
# **Answer:**

# %% [markdown]
# ## Reflection
#
# Write down some notes in your lab notebook about what you've learned in this unit about simulated galaxies. Be sure to include some astronomy and some coding.
